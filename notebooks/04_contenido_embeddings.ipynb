# %% [markdown]
# # 04 — Contenido y Embeddings de Sinopsis
# Se generan embeddings para sinopsis y vectores de géneros/estudios.

# %%
# Nota: la descarga del modelo de sentence-transformers requiere Internet.
from src.features.text_embeddings import SynopsisEmbedder
texts = [
    "Un joven se convierte en héroe tras descubrir poderes ocultos.",
    "Un grupo de estudiantes forma un club para resolver misterios del colegio."
]
emb = SynopsisEmbedder()
vecs = emb.encode(texts)
print(vecs.shape)
