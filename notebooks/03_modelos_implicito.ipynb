# %% [markdown]
# # 03 — Modelos de CF Implícito
# Se entrena un baseline BPR/implicit MF (sintético como ejemplo de flujo).

# %%
import yaml, numpy as np, scipy.sparse as sp
from src.models.cf_implicit import MFImplicitStub

# Matriz binaria sintética (reemplazar por derivaciones de animelist.csv)
n_users, n_items = 1000, 3000
rng = np.random.default_rng(42)
rows = rng.integers(0, n_users, size=20000)
cols = rng.integers(0, n_items, size=20000)
data = np.ones(20000)
X = sp.csr_matrix((data, (rows, cols)), shape=(n_users, n_items))

model = MFImplicitStub(n_factors=64)
model.fit(X)
scores_u0 = model.score_all_items(0)
print('Top-10 items para u0:', np.argsort(scores_u0)[-10:][::-1])
